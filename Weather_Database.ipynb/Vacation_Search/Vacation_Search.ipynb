# %% [markdown]
# # Deliverable 2. Create a Customer Travel Destinations Map
#
# ----
#
# 1. Create a folder called `Vacation_Search` to save all the files related with this deliverable.
#
# 2. Download the `Vacation_Search_starter_code.ipynb` Jupyter notebook,save it into your `Vacation_Search folder`, and rename it as `Vacation_Search.ipynb`.
#
# 3. In the `Vacation_Search.ipynb` file, ensure that the dependencies and the Geoapify API key is imported correctly.
#
# 4. From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`.
#
# 5. Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation.
#
# 6. Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`.
#
# 7. Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows.
#
# 8. Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng".
#
# 9. Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame.
#
# 10. Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city.
#
# 11. Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found".
#
# 12. Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`.
#
# 13. Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the Vacation_Search folder.
#
# 14. Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame. In the point for each city add:
#
#     * The city name
#
#     * The country code
#
#     * The weather description
#
#     * The point's size should be the maximum temperature for the city
#
# 15. Take a screenshot of your map and save it to the `Vacation_Search` folder as `WeatherPy_vacation_map.png`.
#
# ---

# %% [markdown]
# ## Ensure that the dependencies and the Geoapify API key is imported correctly

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# Import API key
from Config import geoapify_key

# %% [markdown]
# ## From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`

# %%
# Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv('../Weather_Database/WeatherPy_Database.csv')

# Display sample data
city_data_df.head()
# Out:
#    City_ID         City Country      Lat      Lng  Max Temp  Humidity  \
# 0        0      Ushuaia      AR -54.8000 -68.3000     56.86        72
# 1        1  Port Alfred      ZA -33.5906  26.8910     73.36        71
# 2        2    Inhambane      MZ -23.8650  35.3833     73.38        83
# 3        3     Sagarejo      GE  41.7340  45.3315     23.43        95
# 4        4         Aksu      CN  41.1231  80.2644     32.85        35
#
#    Cloudiness  Wind Speed Weather Description
# 0           0       12.66           clear sky
# 1           0       10.54           clear sky
# 2          20        4.61          few clouds
# 3          99        2.57     overcast clouds
# 4          99        1.77     overcast clouds

# %% [markdown]
# ## Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation

# %%
# Prompt the user to enter minimum and maximum temperature criteria.
minimum_temp = int(input('What is the minimum temperature you would like for your vacation?'))
maximum_temp = int(input('What is the maximum temperature you would like for your vacation?'))

# %% [markdown]
# ## Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`

# %%
# Filter the city_data_df DataFrame to find the cities that fit the criteria using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df['Max Temp']<= maximum_temp) & (city_data_df['Max Temp'] >= minimum_temp)]

# Display sample data
preferred_cities_df.head()
# Out:
#    City_ID         City Country      Lat      Lng  Max Temp  Humidity  \
# 1        1  Port Alfred      ZA -33.5906  26.8910     73.36        71
# 2        2    Inhambane      MZ -23.8650  35.3833     73.38        83
# 5        5    Bathsheba      BB  13.2167 -59.5167     79.41        78
# 6        6   Vila Velha      BR -20.3297 -40.2925     73.94        95
# 7        7     West Bay      KY  19.3667 -81.4167     75.99        89
#
#    Cloudiness  Wind Speed Weather Description
# 1           0       10.54           clear sky
# 2          20        4.61          few clouds
# 5          40       17.27    scattered clouds
# 6          40        2.30    scattered clouds
# 7           6        1.01           clear sky

# %% [markdown]
# ## Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows

# %%
preferred_cities_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 224 entries, 1 to 683
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City_ID              224 non-null    int64
#  1   City                 224 non-null    object
#  2   Country              223 non-null    object
#  3   Lat                  224 non-null    float64
#  4   Lng                  224 non-null    float64
#  5   Max Temp             224 non-null    float64
#  6   Humidity             224 non-null    int64
#  7   Cloudiness           224 non-null    int64
#  8   Wind Speed           224 non-null    float64
#  9   Weather Description  224 non-null    object
# dtypes: float64(4), int64(3), object(3)
# memory usage: 19.2+ KB

# %%
# Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_travel_cities = preferred_cities_df.dropna()

# Display sample data
clean_travel_cities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 223 entries, 1 to 683
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City_ID              223 non-null    int64
#  1   City                 223 non-null    object
#  2   Country              223 non-null    object
#  3   Lat                  223 non-null    float64
#  4   Lng                  223 non-null    float64
#  5   Max Temp             223 non-null    float64
#  6   Humidity             223 non-null    int64
#  7   Cloudiness           223 non-null    int64
#  8   Wind Speed           223 non-null    float64
#  9   Weather Description  223 non-null    object
# dtypes: float64(4), int64(3), object(3)
# memory usage: 19.2+ KB

# %% [markdown]
# ## Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng"

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_travel_cities[['City', 'Country', 'Max Temp', 'Weather Description', 'Lat', 'Lng']]

# %% [markdown]
# ## Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame

# %%
# Create a new column "Hotel Name".
hotel_df['Hotel Name'] = ''

# Display sample data
hotel_df.head()
# Out:
#           City Country  Max Temp Weather Description      Lat      Lng  \
# 1  Port Alfred      ZA     73.36           clear sky -33.5906  26.8910
# 2    Inhambane      MZ     73.38          few clouds -23.8650  35.3833
# 5    Bathsheba      BB     79.41    scattered clouds  13.2167 -59.5167
# 6   Vila Velha      BR     73.94    scattered clouds -20.3297 -40.2925
# 7     West Bay      KY     75.99           clear sky  19.3667 -81.4167
#
#   Hotel Name
# 1
# 2
# 5
# 6
# 7

# %% [markdown]
# ## Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city

# %%
# Set parameters to search for a hotel
radius = 5000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
    "limit":20
}

# %% [markdown]
# ## Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found"

# %%
# Iterate through the hotel DataFrame

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude and longitude from DataFrame.
    latitude = row['Lat']
    longitude = row['Lng']
    
    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set up the base URL for the Geoapify Places API.
    base_url = "https://api.geoapify.com/v2/places"

    # Make request and retrieve the JSON data by using the params dictionaty
    name_address = requests.get(base_url, params=params).json()
    
    # Convert the API response to JSON format
    # name_address = # YOUR CODE HERE
    
    # Get the first hotel from the results and store the name, if a hotel isn't found set the hotel name as "No hotel found".
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address['features'][0]['properties']['name']
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# Port Alfred - nearest hotel: No hotel found
# Inhambane - nearest hotel: Hotel de Inhambane
# Bathsheba - nearest hotel: Atlantis Hotel
# Vila Velha - nearest hotel: Hotel Prainha
# West Bay - nearest hotel: Bonnie's Arch
# Busselton - nearest hotel: No hotel found
# Takoradi - nearest hotel: Hillcrest
# Touros - nearest hotel: Pousada Atlântico
# Manaure - nearest hotel: hotel palaima
# Mar Del Plata - nearest hotel: Nuevo Ostende
# East London - nearest hotel: No hotel found
# Hithadhoo - nearest hotel: Pebbles Inn
# San Andres - nearest hotel: Hotel Decameron Isleño
# Mahebourg - nearest hotel: Grand Bel Air
# Georgetown - nearest hotel: Page 63 hostel
# Mana - nearest hotel: Le Samana
# Geraldton - nearest hotel: Ocean Centre Hotel
# Grand Gaube - nearest hotel: Coco Villa
# Bubaque - nearest hotel: Chez Julio
# Buchanan - nearest hotel: Phillipmena's Guesthouse
# Richards Bay - nearest hotel: Protea Hotel
# Banda Aceh - nearest hotel: Hotel 61
# Gore - nearest hotel: No hotel found
# Comodoro Rivadavia - nearest hotel: No hotel found
# Victoria - nearest hotel: 四季酒店 Four Seasons Hotel
# Buenaventura - nearest hotel: No hotel found
# Kavaratti - nearest hotel: No hotel found
# Bandarbeyla - nearest hotel: No hotel found
# Galle - nearest hotel: Jungle Hostel Villa
# Muisne - nearest hotel: Hostal Té de Menta
# Acarau - nearest hotel: No hotel found
# Souillac - nearest hotel: Hotel SkylineInn
# Piacabucu - nearest hotel: O Leão
# Lubao - nearest hotel: Hacienda de Gracia Resort
# Araguaina - nearest hotel: No hotel found
# Terra Santa - nearest hotel: Hotel Novo Horizonte
# Dingle - nearest hotel: No hotel found
# Bakel - nearest hotel: Sangacity
# Lucea - nearest hotel: Blue Paloma Bed And Breakfast
# Sao Filipe - nearest hotel: Bela Vista
# Namibe - nearest hotel: Hotel Chik Chik Namibe
# Omboue - nearest hotel: Georges Faustin Aurat
# Praia - nearest hotel: Casa Sodadi
# Mayumba - nearest hotel: Résidence Hôtelière Fabso
# Mbini - nearest hotel: La Trisa
# Cayenne - nearest hotel: Central Hôtel
# Saint-Philippe - nearest hotel: Le Baril
# Port Blair - nearest hotel: Andaman Ocean Breeze
# Arraial Do Cabo - nearest hotel: No hotel found
# Guigue - nearest hotel: No hotel found
# Bambous Virieux - nearest hotel: No hotel found
# Ambilobe - nearest hotel: Hôtel National
# Thinadhoo - nearest hotel: No hotel found
# Hambantota - nearest hotel: Oasis Aurweda Resort Hambathota
# Wanlaweyn - nearest hotel: No hotel found
# Moron - nearest hotel: La Esquina
# Luanda - nearest hotel: Hotel Forum
# Iralaya - nearest hotel: No hotel found
# Kulhudhuffushi - nearest hotel: No hotel found
# Salalah - nearest hotel: Muscat International Hotel
# Tucuma - nearest hotel: No hotel found
# Marsh Harbour - nearest hotel: Lofty Fig Villas
# Cidreira - nearest hotel: Hotel Castelo
# Sinnamary - nearest hotel: Hôtel du fleuve
# Oriximina - nearest hotel: No hotel found
# Warri - nearest hotel: Warri Sapele Road
# Mabaruma - nearest hotel: Monty Brooms Hotel
# Harper - nearest hotel: No hotel found
# Graaff-Reinet - nearest hotel: Profcon Resort
# Nioaque - nearest hotel: Hotel de Trânsito Oficiais
# Eirunepe - nearest hotel: No hotel found
# Conde - nearest hotel: Paladino
# Kudahuvadhoo - nearest hotel: No hotel found
# Belmonte - nearest hotel: No hotel found
# Santa Isabel Do Rio Negro - nearest hotel: Hotel Maikon
# Caravelas - nearest hotel: Pousada dos Navegantes
# Conceicao Das Alagoas - nearest hotel: No hotel found
# Saint-Joseph - nearest hotel: No hotel found
# Sao Sebastiao - nearest hotel: Hotel do Sol Executive
# Quelimane - nearest hotel: Mabassa
# Luis Correia - nearest hotel: Hotel Amaro
# Keti Bandar - nearest hotel: No hotel found
# Cabedelo - nearest hotel: No hotel found
# Kalmunai - nearest hotel: Saji new food
# Angoche - nearest hotel: Hotel Quirimbas
# Carnarvon - nearest hotel: No hotel found
# Bonthe - nearest hotel: No hotel found
# Berbera - nearest hotel: Al Madina Hotel
# Sena Madureira - nearest hotel: No hotel found
# San Rafael - nearest hotel: Hotel Regional
# Fonseca - nearest hotel: No hotel found
# Bodden Town - nearest hotel: Turtle Nest Inn
# Porto Walter - nearest hotel: No hotel found
# Kang - nearest hotel: Nkisi Guest House
# Grajau - nearest hotel: Torre Palace Hotel
# Mogadishu - nearest hotel: SYL Hotel
# Mandera - nearest hotel: Kornesh Hotel and Lodging
# Charlestown - nearest hotel: Warners Bay Hotel
# Cueto - nearest hotel: No hotel found
# Kodinar - nearest hotel: No hotel found
# La Fria - nearest hotel: Hotel Nuestra Señora de Coromoto
# Baillif - nearest hotel: Hôtel de Rocroy
# Cap Malheureux - nearest hotel: Cape Garden
# Ayolas - nearest hotel: No hotel found
# Lekoni - nearest hotel: Le rdv des chasseurs
# Knysna - nearest hotel: Graywood Hotel
# Pondicherry - nearest hotel: Restaurant Paris Residency
# Kalugumalai - nearest hotel: No hotel found
# Matara - nearest hotel: Villa Palm Breeze
# Itarema - nearest hotel: Pousada Oásis
# Mangrol - nearest hotel: No hotel found
# Young - nearest hotel: Hotel El Galeon
# Kralendijk - nearest hotel: Hotel Bonaire Inn
# Salinopolis - nearest hotel: Hotel Salinópolis
# Ugoofaaru - nearest hotel: No hotel found
# Wattegama - nearest hotel: No hotel found
# Aquin - nearest hotel: Hotel Aldy
# Benguela - nearest hotel: Hotel Moibela
# Tabou - nearest hotel: hôtel le rochet
# Lima - nearest hotel: Hotel Peach Garden
# Cartagena - nearest hotel: Hotel Bellamar
# Ambovombe - nearest hotel: La source
# Baracoa - nearest hotel: Casa
# Sao Geraldo Do Araguaia - nearest hotel: Tomazi Hotel
# Oussouye - nearest hotel: Campement Alulum
# Maracanau - nearest hotel: Ibis
# Guarapari - nearest hotel: Osmar Hotel
# Sinazongwe - nearest hotel: Lake View Lodge
# Kattivakkam - nearest hotel: No hotel found
# Boa Vista - nearest hotel: Aipana Plaza Hotel
# Srivardhan - nearest hotel: No hotel found
# Bhuj - nearest hotel: Hotel Prince
# Beroroha - nearest hotel: No hotel found
# Antalaha - nearest hotel: Hôtel Florida
# Clarence Town - nearest hotel: Erringhi Hotel
# Venezuela - nearest hotel: No hotel found
# Japura - nearest hotel: No hotel found
# Les Cayes - nearest hotel: No hotel found
# Inirida - nearest hotel: Residencias El Turista del Guainia
# Mananjary - nearest hotel: Ideal Hotel Annexe
# Quatre Cocos - nearest hotel: Horisun
# Coreau - nearest hotel: No hotel found
# Morant Bay - nearest hotel: Morant Villas
# Nacala - nearest hotel: Indico Apart Hotel 2
# Pitimbu - nearest hotel: Pousada Brisa Mar
# Olinda - nearest hotel: Fidji Motel
# Santa Cruz - nearest hotel: Aviador Hotel Boutique
# Ballina - nearest hotel: Ballina Beach Resort
# Samana - nearest hotel: Hotel Cotubanamá
# Sao Jose Da Coroa Grande - nearest hotel: Hotel do Sol
# Trairi - nearest hotel: No hotel found
# Karimnagar - nearest hotel: Kalpana Hotel
# Puerto Cabezas - nearest hotel: Hotel Caribe
# Ambanja - nearest hotel: Hôtel Salama Rose
# Carutapera - nearest hotel: No hotel found
# Zabid - nearest hotel: No hotel found
# Bengkulu - nearest hotel: Dena Hotel
# Zaraza - nearest hotel: No hotel found
# Puerto Suarez - nearest hotel: No hotel found
# Kruisfontein - nearest hotel: No hotel found
# Jibuti - nearest hotel: No hotel found
# Vasai - nearest hotel: No hotel found
# General Pico - nearest hotel: Euskadi Hotel
# Yanam - nearest hotel: No hotel found
# Varadero - nearest hotel: Hotel Cuatro Palmas
# Tucuman - nearest hotel: Suites San Luis
# General Roca - nearest hotel: Hotel Austral
# Bell Ville - nearest hotel: No hotel found
# Humaita - nearest hotel: Humaita Quality Hotel
# Sakaraha - nearest hotel: Palace Club
# Sao Joao Da Barra - nearest hotel: Pousada Mediterrâneo
# Puerto Leguizamo - nearest hotel: Hotel Girasoles
# Manta - nearest hotel: La Gaviota
# Sassandra - nearest hotel: Hotel Le Pollet
# Mitsamiouli - nearest hotel: Hotel le Paradis
# Kintampo - nearest hotel: No hotel found
# Villa Bruzual - nearest hotel: Hotel Turístico Sol de Arichuna
# Batticaloa - nearest hotel: Lake View Hotel
# Canalete - nearest hotel: No hotel found
# Tucurui - nearest hotel: No hotel found
# Maceio - nearest hotel: Maceió Hostel e Pousada
# Road Town - nearest hotel: No hotel found
# Paragominas - nearest hotel: No hotel found
# Le Port - nearest hotel: No hotel found
# Irituia - nearest hotel: No hotel found
# Port-Gentil - nearest hotel: Tara-Mé
# Padang - nearest hotel: losmen Surya
# Sambava - nearest hotel: Royal Sava Hôtel
# Veraval - nearest hotel: Shyam
# Pauini - nearest hotel: No hotel found
# Farafangana - nearest hotel: Le Concombre Masqué
# Saint-Pierre - nearest hotel: Tropic Hotel
# Sur - nearest hotel: Sur Hotel
# Saint-Leu - nearest hotel: Iloha Seaview Hôtel
# Sao Felix Do Xingu - nearest hotel: Hotel Terraço
# Lethem - nearest hotel: Hotel Amazonas
# New Amsterdam - nearest hotel: Church View Hotel
# Coxim - nearest hotel: Avendita
# Khandbari - nearest hotel: Guesthouse
# Huicungo - nearest hotel: No hotel found
# Pontes E Lacerda - nearest hotel: Hotel Avenida
# Codajas - nearest hotel: No hotel found
# Santa Rosa - nearest hotel: JARS RESORT
# Beloha - nearest hotel: No hotel found
# Pedasi - nearest hotel: Dim's Hostal
# Soyo - nearest hotel: Hotel Maria Teres
# Narasannapeta - nearest hotel: No hotel found
# Esperantina - nearest hotel: No hotel found
# The Valley - nearest hotel: CeBlue
# George Town - nearest hotel: Page 63 hostel
# Isla Mujeres - nearest hotel: Villa La Bella
# Tucupita - nearest hotel: Hotel salma suit
# Chone - nearest hotel: Atahualpa de oro
# Alibag - nearest hotel: Hira Laxmi Residency
# Araguacu - nearest hotel: No hotel found
# Dunmore Town - nearest hotel: The Landing Hotel & Restaurant
# Sarankhola - nearest hotel: No hotel found
# Meulaboh - nearest hotel: Hotel Meuligou
# Miracema Do Tocantins - nearest hotel: No hotel found
# Maraa - nearest hotel: No hotel found
# Cobija - nearest hotel: Hotel El Cristo
# Santa Marta - nearest hotel: Casa Mita
# Rawson - nearest hotel: Hotel Deportivo
#                       City Country  Max Temp Weather Description      Lat  \
# 1              Port Alfred      ZA     73.36           clear sky -33.5906
# 2                Inhambane      MZ     73.38          few clouds -23.8650
# 5                Bathsheba      BB     79.41    scattered clouds  13.2167
# 6               Vila Velha      BR     73.94    scattered clouds -20.3297
# 7                 West Bay      KY     75.99           clear sky  19.3667
# ..                     ...     ...       ...                 ...      ...
# 671  Miracema Do Tocantins      BR     71.38       broken clouds  -9.5618
# 673                  Maraa      BR     70.81       broken clouds  -1.8333
# 679                 Cobija      BO     77.29     overcast clouds -11.0267
# 681            Santa Marta      CO     81.90          few clouds  11.2408
# 683                 Rawson      AR     80.49       broken clouds -43.3002
#
#          Lng          Hotel Name
# 1    26.8910      No hotel found
# 2    35.3833  Hotel de Inhambane
# 5   -59.5167      Atlantis Hotel
# 6   -40.2925       Hotel Prainha
# 7   -81.4167       Bonnie's Arch
# ..       ...                 ...
# 671 -48.3967      No hotel found
# 673 -65.3667      No hotel found
# 679 -68.7692     Hotel El Cristo
# 681 -74.1990           Casa Mita
# 683 -65.1023     Hotel Deportivo
#
# [223 rows x 7 columns]

# %% [markdown]
# ## Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`

# %%
# Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df.loc[(hotel_df['Hotel Name'] != 'No hotel found')]

# Display sample data
clean_hotel_df.head()
# Out:
#           City Country  Max Temp Weather Description      Lat      Lng  \
# 2    Inhambane      MZ     73.38          few clouds -23.8650  35.3833
# 5    Bathsheba      BB     79.41    scattered clouds  13.2167 -59.5167
# 6   Vila Velha      BR     73.94    scattered clouds -20.3297 -40.2925
# 7     West Bay      KY     75.99           clear sky  19.3667 -81.4167
# 10    Takoradi      GH     78.17       broken clouds   4.8845  -1.7554
#
#             Hotel Name
# 2   Hotel de Inhambane
# 5       Atlantis Hotel
# 6        Hotel Prainha
# 7        Bonnie's Arch
# 10           Hillcrest

# %% [markdown]
# ## Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the `Vacation_Search`` folder

# %%
# Create the output File (CSV)
export_file = '../Vacation_Search/WeatherPy_Vacation.csv'

# Export the City_Data into a csv
clean_hotel_df.to_csv(export_file, index_label='City_ID')

# %% [markdown]
# ## Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame.
#
# In the point for each city add:
#
# * The city name
# * The country code
# * The weather description
# * The point's size should be the maximum temperature for the city

# %%
# Configure the map plot
hotel_map = clean_hotel_df.hvplot.points(
    'Lng',
    'Lat',
    geo = True,
    tiles = 'OSM',
    frame_width = 700,
    frame_height = 500,
    size = 'Max Temp',
    scale = 1,
    color = 'City',
    hover_cols = ['City', 'Country', 'Hotel Name', 'Weather Description']
)

# Display the map
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp,Country,Hotel Name,Weather Description)
