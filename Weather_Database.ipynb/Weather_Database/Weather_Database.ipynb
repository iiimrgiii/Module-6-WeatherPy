# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90, 90, size=2000)
lngs = np.random.uniform(-90, 90, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 745

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from Config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = f'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}'

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]  
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(), 
                         "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | port alfred
# Processing Record 3 of Set 1 | inhambane
# Processing Record 4 of Set 1 | sagarejo
# Processing Record 5 of Set 1 | aksu
# Processing Record 6 of Set 1 | bathsheba
# Processing Record 7 of Set 1 | vila velha
# Processing Record 8 of Set 1 | west bay
# Processing Record 9 of Set 1 | grimari
# City not found. Skipping...
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | kirovskiy
# Processing Record 12 of Set 1 | takoradi
# Processing Record 13 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 1 | brae
# Processing Record 15 of Set 1 | joniskelis
# Processing Record 16 of Set 1 | shetpe
# Processing Record 17 of Set 1 | villacarrillo
# Processing Record 18 of Set 1 | chuy
# Processing Record 19 of Set 1 | hermanus
# Processing Record 20 of Set 1 | touros
# Processing Record 21 of Set 1 | taltal
# Processing Record 22 of Set 1 | jasper
# Processing Record 23 of Set 1 | urengoy
# Processing Record 24 of Set 1 | manaure
# Processing Record 25 of Set 1 | mar del plata
# Processing Record 26 of Set 1 | ouallam
# Processing Record 27 of Set 1 | east london
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | hithadhoo
# Processing Record 30 of Set 1 | san andres
# Processing Record 31 of Set 1 | husavik
# Processing Record 32 of Set 1 | mahebourg
# Processing Record 33 of Set 1 | georgetown
# Processing Record 34 of Set 1 | dikson
# Processing Record 35 of Set 1 | aripuana
# Processing Record 36 of Set 1 | kosh-agach
# Processing Record 37 of Set 1 | koslan
# Processing Record 38 of Set 1 | roald
# Processing Record 39 of Set 1 | barcelona
# Processing Record 40 of Set 1 | upernavik
# Processing Record 41 of Set 1 | kaele
# Processing Record 42 of Set 1 | jardim
# Processing Record 43 of Set 1 | pangody
# Processing Record 44 of Set 1 | bredasdorp
# Processing Record 45 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 1 | coquimbo
# Processing Record 47 of Set 1 | mana
# Processing Record 48 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 1 | geraldton
# Processing Record 50 of Set 1 | grand gaube
# Processing Record 1 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 2 | saint george
# Processing Record 3 of Set 2 | port elizabeth
# Processing Record 4 of Set 2 | bubaque
# Processing Record 5 of Set 2 | iqaluit
# Processing Record 6 of Set 2 | buchanan
# Processing Record 7 of Set 2 | richards bay
# Processing Record 8 of Set 2 | raga
# Processing Record 9 of Set 2 | banda aceh
# Processing Record 10 of Set 2 | qaanaaq
# Processing Record 11 of Set 2 | saint-augustin
# Processing Record 12 of Set 2 | clyde river
# Processing Record 13 of Set 2 | gore
# Processing Record 14 of Set 2 | comodoro rivadavia
# Processing Record 15 of Set 2 | longyearbyen
# Processing Record 16 of Set 2 | victoria
# Processing Record 17 of Set 2 | povolzhskiy
# Processing Record 18 of Set 2 | oruro
# Processing Record 19 of Set 2 | mari-turek
# Processing Record 20 of Set 2 | orangeburg
# Processing Record 21 of Set 2 | seeboden
# Processing Record 22 of Set 2 | castro
# Processing Record 23 of Set 2 | cariamanga
# Processing Record 24 of Set 2 | koygorodok
# Processing Record 25 of Set 2 | yashkul
# Processing Record 26 of Set 2 | laguna
# Processing Record 27 of Set 2 | ulze
# City not found. Skipping...
# Processing Record 28 of Set 2 | velesin
# Processing Record 29 of Set 2 | ceres
# Processing Record 30 of Set 2 | buenaventura
# Processing Record 31 of Set 2 | uyuni
# Processing Record 32 of Set 2 | kavaratti
# Processing Record 33 of Set 2 | saint-honore
# Processing Record 34 of Set 2 | collingwood
# Processing Record 35 of Set 2 | bandarbeyla
# Processing Record 36 of Set 2 | penzance
# Processing Record 37 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 2 | rio grande
# Processing Record 39 of Set 2 | tunduru
# City not found. Skipping...
# Processing Record 40 of Set 2 | galle
# Processing Record 41 of Set 2 | cape town
# Processing Record 42 of Set 2 | moussoro
# Processing Record 43 of Set 2 | muisne
# Processing Record 44 of Set 2 | eloi mendes
# Processing Record 45 of Set 2 | klaksvik
# Processing Record 46 of Set 2 | acarau
# Processing Record 47 of Set 2 | vila franca do campo
# Processing Record 48 of Set 2 | chernushka
# Processing Record 49 of Set 2 | rocha
# Processing Record 50 of Set 2 | souillac
# Processing Record 1 of Set 3 | hualmay
# Processing Record 2 of Set 3 | piacabucu
# Processing Record 3 of Set 3 | antofagasta
# Processing Record 4 of Set 3 | luderitz
# Processing Record 5 of Set 3 | tabas
# Processing Record 6 of Set 3 | margate
# Processing Record 7 of Set 3 | awbari
# Processing Record 8 of Set 3 | lubao
# Processing Record 9 of Set 3 | araguaina
# Processing Record 10 of Set 3 | terra santa
# Processing Record 11 of Set 3 | nouakchott
# Processing Record 12 of Set 3 | jos
# Processing Record 13 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 3 | ponta do sol
# Processing Record 15 of Set 3 | dingle
# Processing Record 16 of Set 3 | bakel
# Processing Record 17 of Set 3 | lucea
# Processing Record 18 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 3 | sao filipe
# Processing Record 20 of Set 3 | kentau
# Processing Record 21 of Set 3 | nanortalik
# Processing Record 22 of Set 3 | svatove
# Processing Record 23 of Set 3 | mudanya
# Processing Record 24 of Set 3 | boddam
# Processing Record 25 of Set 3 | namibe
# Processing Record 26 of Set 3 | molchanovo
# Processing Record 27 of Set 3 | tasiilaq
# Processing Record 28 of Set 3 | omboue
# Processing Record 29 of Set 3 | praia
# Processing Record 30 of Set 3 | walvis bay
# Processing Record 31 of Set 3 | ilulissat
# Processing Record 32 of Set 3 | mayumba
# Processing Record 33 of Set 3 | hofn
# Processing Record 34 of Set 3 | mbini
# Processing Record 35 of Set 3 | granadilla de abona
# Processing Record 36 of Set 3 | dakar
# Processing Record 37 of Set 3 | kitui
# Processing Record 38 of Set 3 | mahadday weyne
# City not found. Skipping...
# Processing Record 39 of Set 3 | cayenne
# Processing Record 40 of Set 3 | saint-philippe
# Processing Record 41 of Set 3 | arlit
# Processing Record 42 of Set 3 | port blair
# Processing Record 43 of Set 3 | arraial do cabo
# Processing Record 44 of Set 3 | kumluca
# Processing Record 45 of Set 3 | ostersund
# Processing Record 46 of Set 3 | tiznit
# Processing Record 47 of Set 3 | akhtanizovskaya
# Processing Record 48 of Set 3 | guigue
# Processing Record 49 of Set 3 | bambous virieux
# Processing Record 50 of Set 3 | ambilobe
# Processing Record 1 of Set 4 | thinadhoo
# Processing Record 2 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 4 | port shepstone
# Processing Record 4 of Set 4 | hambantota
# Processing Record 5 of Set 4 | codrington
# Processing Record 6 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 4 | yeletskiy
# City not found. Skipping...
# Processing Record 8 of Set 4 | yar-sale
# Processing Record 9 of Set 4 | umm bab
# Processing Record 10 of Set 4 | kinsale
# Processing Record 11 of Set 4 | dalmatovo
# Processing Record 12 of Set 4 | saldanha
# Processing Record 13 of Set 4 | wanlaweyn
# Processing Record 14 of Set 4 | adrar
# Processing Record 15 of Set 4 | havre-saint-pierre
# Processing Record 16 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 17 of Set 4 | sanawad
# Processing Record 18 of Set 4 | caconda
# Processing Record 19 of Set 4 | mamlyutka
# Processing Record 20 of Set 4 | lebu
# Processing Record 21 of Set 4 | ribeira grande
# Processing Record 22 of Set 4 | moron
# Processing Record 23 of Set 4 | arrecife
# Processing Record 24 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 4 | luanda
# Processing Record 26 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 27 of Set 4 | iralaya
# Processing Record 28 of Set 4 | kulhudhuffushi
# Processing Record 29 of Set 4 | salalah
# Processing Record 30 of Set 4 | kjollefjord
# Processing Record 31 of Set 4 | eyemouth
# Processing Record 32 of Set 4 | tucuma
# Processing Record 33 of Set 4 | narsaq
# Processing Record 34 of Set 4 | albany
# Processing Record 35 of Set 4 | andenes
# Processing Record 36 of Set 4 | marsh harbour
# Processing Record 37 of Set 4 | rudnya
# Processing Record 38 of Set 4 | cidreira
# Processing Record 39 of Set 4 | aranos
# Processing Record 40 of Set 4 | torbay
# Processing Record 41 of Set 4 | filingue
# Processing Record 42 of Set 4 | kali
# Processing Record 43 of Set 4 | astana
# Processing Record 44 of Set 4 | sinnamary
# Processing Record 45 of Set 4 | sabha
# Processing Record 46 of Set 4 | saint-nazaire
# Processing Record 47 of Set 4 | westport
# Processing Record 48 of Set 4 | faya
# Processing Record 49 of Set 4 | oriximina
# Processing Record 50 of Set 4 | warri
# Processing Record 1 of Set 5 | litoral del san juan
# City not found. Skipping...
# Processing Record 2 of Set 5 | krutinka
# Processing Record 3 of Set 5 | virginia beach
# Processing Record 4 of Set 5 | mabaruma
# Processing Record 5 of Set 5 | pyshma
# Processing Record 6 of Set 5 | buncrana
# Processing Record 7 of Set 5 | necochea
# Processing Record 8 of Set 5 | harbour breton
# Processing Record 9 of Set 5 | patacamaya
# Processing Record 10 of Set 5 | buraydah
# Processing Record 11 of Set 5 | rosignano marittimo
# Processing Record 12 of Set 5 | campagna
# Processing Record 13 of Set 5 | harper
# Processing Record 14 of Set 5 | graaff-reinet
# Processing Record 15 of Set 5 | jiroft
# City not found. Skipping...
# Processing Record 16 of Set 5 | manacor
# Processing Record 17 of Set 5 | murgab
# Processing Record 18 of Set 5 | hamilton
# Processing Record 19 of Set 5 | nioaque
# Processing Record 20 of Set 5 | nantucket
# Processing Record 21 of Set 5 | aswan
# Processing Record 22 of Set 5 | gezing
# Processing Record 23 of Set 5 | punta arenas
# Processing Record 24 of Set 5 | nalut
# Processing Record 25 of Set 5 | lubumbashi
# Processing Record 26 of Set 5 | hvammstangi
# City not found. Skipping...
# Processing Record 27 of Set 5 | eirunepe
# Processing Record 28 of Set 5 | dawlatabad
# Processing Record 29 of Set 5 | tazovskiy
# Processing Record 30 of Set 5 | jasidih
# Processing Record 31 of Set 5 | mao
# Processing Record 32 of Set 5 | tome-acu
# City not found. Skipping...
# Processing Record 33 of Set 5 | copiapo
# Processing Record 34 of Set 5 | costa rica
# Processing Record 35 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 5 | santa lucia
# Processing Record 37 of Set 5 | sergokala
# Processing Record 38 of Set 5 | conde
# Processing Record 39 of Set 5 | luau
# Processing Record 40 of Set 5 | kudahuvadhoo
# Processing Record 41 of Set 5 | belmonte
# Processing Record 42 of Set 5 | yevpatoriya
# Processing Record 43 of Set 5 | usinsk
# Processing Record 44 of Set 5 | blois
# Processing Record 45 of Set 5 | santa isabel do rio negro
# Processing Record 46 of Set 5 | agadez
# Processing Record 47 of Set 5 | roquetas de mar
# Processing Record 48 of Set 5 | kharabali
# Processing Record 49 of Set 5 | caravelas
# Processing Record 50 of Set 5 | conceicao das alagoas
# Processing Record 1 of Set 6 | zbarazh
# Processing Record 2 of Set 6 | alford
# Processing Record 3 of Set 6 | saint-joseph
# Processing Record 4 of Set 6 | berlevag
# Processing Record 5 of Set 6 | sao sebastiao
# Processing Record 6 of Set 6 | trofors
# Processing Record 7 of Set 6 | quelimane
# Processing Record 8 of Set 6 | luis correia
# Processing Record 9 of Set 6 | keti bandar
# Processing Record 10 of Set 6 | cabedelo
# Processing Record 11 of Set 6 | krasnoarmeysk
# Processing Record 12 of Set 6 | cheremshanka
# Processing Record 13 of Set 6 | maun
# Processing Record 14 of Set 6 | adre
# Processing Record 15 of Set 6 | opuwo
# Processing Record 16 of Set 6 | hvittingfoss
# Processing Record 17 of Set 6 | chicama
# Processing Record 18 of Set 6 | sidrolandia
# Processing Record 19 of Set 6 | vardo
# Processing Record 20 of Set 6 | agirish
# Processing Record 21 of Set 6 | kondinskoye
# Processing Record 22 of Set 6 | chachapoyas
# Processing Record 23 of Set 6 | zaranj
# Processing Record 24 of Set 6 | kilembe
# Processing Record 25 of Set 6 | villmergen
# Processing Record 26 of Set 6 | paamiut
# Processing Record 27 of Set 6 | nara
# Processing Record 28 of Set 6 | parry sound
# Processing Record 29 of Set 6 | kalmunai
# Processing Record 30 of Set 6 | purpe
# Processing Record 31 of Set 6 | bilma
# Processing Record 32 of Set 6 | angoche
# Processing Record 33 of Set 6 | pryyutivka
# Processing Record 34 of Set 6 | rennes
# Processing Record 35 of Set 6 | ituporanga
# Processing Record 36 of Set 6 | carnarvon
# Processing Record 37 of Set 6 | bonavista
# Processing Record 38 of Set 6 | breytovo
# Processing Record 39 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 6 | belomorsk
# Processing Record 41 of Set 6 | bonthe
# Processing Record 42 of Set 6 | azar shahr
# City not found. Skipping...
# Processing Record 43 of Set 6 | berbera
# Processing Record 44 of Set 6 | jumla
# Processing Record 45 of Set 6 | sena madureira
# Processing Record 46 of Set 6 | moche
# Processing Record 47 of Set 6 | san rafael
# Processing Record 48 of Set 6 | treinta y tres
# Processing Record 49 of Set 6 | fonseca
# Processing Record 50 of Set 6 | kamenka
# Processing Record 1 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 2 of Set 7 | oranjemund
# Processing Record 3 of Set 7 | bertrix
# Processing Record 4 of Set 7 | bodden town
# Processing Record 5 of Set 7 | bulaevo
# Processing Record 6 of Set 7 | porto walter
# Processing Record 7 of Set 7 | kang
# Processing Record 8 of Set 7 | saint anthony
# Processing Record 9 of Set 7 | fremont
# Processing Record 10 of Set 7 | gazli
# Processing Record 11 of Set 7 | grajau
# Processing Record 12 of Set 7 | mogadishu
# Processing Record 13 of Set 7 | kutum
# Processing Record 14 of Set 7 | makungu
# Processing Record 15 of Set 7 | aksarka
# Processing Record 16 of Set 7 | goianesia
# Processing Record 17 of Set 7 | mandera
# Processing Record 18 of Set 7 | marzuq
# Processing Record 19 of Set 7 | charlestown
# Processing Record 20 of Set 7 | lipari
# Processing Record 21 of Set 7 | aktau
# Processing Record 22 of Set 7 | brezoi
# Processing Record 23 of Set 7 | nuuk
# Processing Record 24 of Set 7 | cueto
# Processing Record 25 of Set 7 | olsztyn
# Processing Record 26 of Set 7 | akhmim
# Processing Record 27 of Set 7 | kodinar
# Processing Record 28 of Set 7 | la fria
# Processing Record 29 of Set 7 | baillif
# Processing Record 30 of Set 7 | sansepolcro
# Processing Record 31 of Set 7 | cap malheureux
# Processing Record 32 of Set 7 | imbituba
# Processing Record 33 of Set 7 | kasama
# Processing Record 34 of Set 7 | thompson
# Processing Record 35 of Set 7 | ayolas
# Processing Record 36 of Set 7 | atasu
# Processing Record 37 of Set 7 | vestmannaeyjar
# Processing Record 38 of Set 7 | lagoa
# Processing Record 39 of Set 7 | qaqortoq
# Processing Record 40 of Set 7 | bad sachsa
# Processing Record 41 of Set 7 | new castle
# Processing Record 42 of Set 7 | llanes
# Processing Record 43 of Set 7 | kautokeino
# Processing Record 44 of Set 7 | wukari
# Processing Record 45 of Set 7 | kemerovo
# Processing Record 46 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 47 of Set 7 | enterprise
# Processing Record 48 of Set 7 | dongobesh
# Processing Record 49 of Set 7 | qibili
# City not found. Skipping...
# Processing Record 50 of Set 7 | lekoni
# Processing Record 1 of Set 8 | karamay
# City not found. Skipping...
# Processing Record 2 of Set 8 | lake city
# Processing Record 3 of Set 8 | teguldet
# Processing Record 4 of Set 8 | passo fundo
# Processing Record 5 of Set 8 | sochi
# Processing Record 6 of Set 8 | knysna
# Processing Record 7 of Set 8 | karpathos
# Processing Record 8 of Set 8 | gollere
# City not found. Skipping...
# Processing Record 9 of Set 8 | liapades
# City not found. Skipping...
# Processing Record 10 of Set 8 | praia da vitoria
# Processing Record 11 of Set 8 | santa isabel
# Processing Record 12 of Set 8 | otukpo
# Processing Record 13 of Set 8 | pondicherry
# Processing Record 14 of Set 8 | oneida
# Processing Record 15 of Set 8 | kalugumalai
# Processing Record 16 of Set 8 | petrozavodsk
# Processing Record 17 of Set 8 | chastyye
# Processing Record 18 of Set 8 | san cristobal
# Processing Record 19 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 8 | sagar
# Processing Record 21 of Set 8 | huancavelica
# Processing Record 22 of Set 8 | ekibastuz
# Processing Record 23 of Set 8 | matara
# Processing Record 24 of Set 8 | itarema
# Processing Record 25 of Set 8 | soavinandriana
# Processing Record 26 of Set 8 | mangrol
# Processing Record 27 of Set 8 | nouadhibou
# Processing Record 28 of Set 8 | mincivan
# Processing Record 29 of Set 8 | young
# Processing Record 30 of Set 8 | vaals
# Processing Record 31 of Set 8 | wolow
# Processing Record 32 of Set 8 | inzer
# Processing Record 33 of Set 8 | kralendijk
# Processing Record 34 of Set 8 | salinopolis
# Processing Record 35 of Set 8 | areosa
# Processing Record 36 of Set 8 | ugoofaaru
# Processing Record 37 of Set 8 | wattegama
# Processing Record 38 of Set 8 | impfondo
# Processing Record 39 of Set 8 | salta
# Processing Record 40 of Set 8 | aquin
# Processing Record 41 of Set 8 | benguela
# Processing Record 42 of Set 8 | tabou
# Processing Record 43 of Set 8 | lima
# Processing Record 44 of Set 8 | menongue
# Processing Record 45 of Set 8 | cartagena
# Processing Record 46 of Set 8 | sakakah
# Processing Record 47 of Set 8 | lampa
# Processing Record 48 of Set 8 | oum hadjer
# Processing Record 49 of Set 8 | dharchula
# Processing Record 50 of Set 8 | ambovombe
# Processing Record 1 of Set 9 | plouzane
# Processing Record 2 of Set 9 | coihaique
# Processing Record 3 of Set 9 | baracoa
# Processing Record 4 of Set 9 | kindu
# Processing Record 5 of Set 9 | sao geraldo do araguaia
# Processing Record 6 of Set 9 | pamplona
# Processing Record 7 of Set 9 | branford
# Processing Record 8 of Set 9 | nsanje
# Processing Record 9 of Set 9 | lafiagi
# Processing Record 10 of Set 9 | oussouye
# Processing Record 11 of Set 9 | karpogory
# Processing Record 12 of Set 9 | najran
# Processing Record 13 of Set 9 | maracanau
# Processing Record 14 of Set 9 | vidyayevo
# Processing Record 15 of Set 9 | khudumelapye
# Processing Record 16 of Set 9 | skibbereen
# Processing Record 17 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 18 of Set 9 | yarmouth
# Processing Record 19 of Set 9 | severnyy
# Processing Record 20 of Set 9 | havelock
# Processing Record 21 of Set 9 | lucapa
# Processing Record 22 of Set 9 | sroda wielkopolska
# Processing Record 23 of Set 9 | guarapari
# Processing Record 24 of Set 9 | velyka bilozerka
# Processing Record 25 of Set 9 | sinazongwe
# Processing Record 26 of Set 9 | kattivakkam
# Processing Record 27 of Set 9 | conneaut
# Processing Record 28 of Set 9 | ileza
# Processing Record 29 of Set 9 | kneza
# City not found. Skipping...
# Processing Record 30 of Set 9 | boa vista
# Processing Record 31 of Set 9 | tombouctou
# Processing Record 32 of Set 9 | srivardhan
# Processing Record 33 of Set 9 | bhuj
# Processing Record 34 of Set 9 | tessalit
# Processing Record 35 of Set 9 | inyonga
# Processing Record 36 of Set 9 | bud
# Processing Record 37 of Set 9 | carbondale
# Processing Record 38 of Set 9 | botwood
# Processing Record 39 of Set 9 | dax
# Processing Record 40 of Set 9 | beroroha
# Processing Record 41 of Set 9 | raudeberg
# Processing Record 42 of Set 9 | huallanca
# Processing Record 43 of Set 9 | rio gallegos
# Processing Record 44 of Set 9 | antalaha
# Processing Record 45 of Set 9 | chekmagush
# Processing Record 46 of Set 9 | qeshm
# Processing Record 47 of Set 9 | bayir
# Processing Record 48 of Set 9 | ferme-neuve
# Processing Record 49 of Set 9 | clarence town
# Processing Record 50 of Set 9 | venezuela
# Processing Record 1 of Set 10 | japura
# Processing Record 2 of Set 10 | matay
# Processing Record 3 of Set 10 | mandali
# Processing Record 4 of Set 10 | matao
# Processing Record 5 of Set 10 | les cayes
# Processing Record 6 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 7 of Set 10 | inirida
# Processing Record 8 of Set 10 | vedaranniyam
# City not found. Skipping...
# Processing Record 9 of Set 10 | karasjok
# Processing Record 10 of Set 10 | mananjary
# Processing Record 11 of Set 10 | ostrovnoy
# Processing Record 12 of Set 10 | kalmar
# Processing Record 13 of Set 10 | camacha
# Processing Record 14 of Set 10 | quatre cocos
# Processing Record 15 of Set 10 | damghan
# Processing Record 16 of Set 10 | coreau
# Processing Record 17 of Set 10 | zhanakorgan
# Processing Record 18 of Set 10 | morant bay
# Processing Record 19 of Set 10 | gazojak
# Processing Record 20 of Set 10 | nacala
# Processing Record 21 of Set 10 | bongandanga
# Processing Record 22 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 23 of Set 10 | surami
# Processing Record 24 of Set 10 | aljezur
# Processing Record 25 of Set 10 | pitimbu
# Processing Record 26 of Set 10 | olinda
# Processing Record 27 of Set 10 | santa cruz
# Processing Record 28 of Set 10 | ramshir
# Processing Record 29 of Set 10 | belyy yar
# Processing Record 30 of Set 10 | filadelfia
# Processing Record 31 of Set 10 | lomza
# Processing Record 32 of Set 10 | portknockie
# Processing Record 33 of Set 10 | ballina
# Processing Record 34 of Set 10 | jalu
# Processing Record 35 of Set 10 | grindavik
# Processing Record 36 of Set 10 | hlobyne
# Processing Record 37 of Set 10 | samana
# Processing Record 38 of Set 10 | talnakh
# Processing Record 39 of Set 10 | sao jose da coroa grande
# Processing Record 40 of Set 10 | brewster
# Processing Record 41 of Set 10 | azimur
# City not found. Skipping...
# Processing Record 42 of Set 10 | trairi
# Processing Record 43 of Set 10 | sant feliu de guixols
# Processing Record 44 of Set 10 | karimnagar
# Processing Record 45 of Set 10 | utrecht
# Processing Record 46 of Set 10 | durham
# Processing Record 47 of Set 10 | puerto cabezas
# Processing Record 48 of Set 10 | san carlos de bariloche
# Processing Record 49 of Set 10 | ambanja
# Processing Record 50 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 1 of Set 11 | druzhba
# Processing Record 2 of Set 11 | aromashevo
# Processing Record 3 of Set 11 | gravdal
# Processing Record 4 of Set 11 | herat
# Processing Record 5 of Set 11 | carutapera
# Processing Record 6 of Set 11 | komsomolskiy
# Processing Record 7 of Set 11 | sorland
# Processing Record 8 of Set 11 | shihezi
# Processing Record 9 of Set 11 | chalons-en-champagne
# Processing Record 10 of Set 11 | ivangorod
# Processing Record 11 of Set 11 | ponta delgada
# Processing Record 12 of Set 11 | khunti
# Processing Record 13 of Set 11 | sistranda
# Processing Record 14 of Set 11 | peniche
# Processing Record 15 of Set 11 | ancud
# Processing Record 16 of Set 11 | talcahuano
# Processing Record 17 of Set 11 | altay
# Processing Record 18 of Set 11 | ilinskiy
# Processing Record 19 of Set 11 | zabid
# Processing Record 20 of Set 11 | bengkulu
# Processing Record 21 of Set 11 | zaraza
# Processing Record 22 of Set 11 | am timan
# Processing Record 23 of Set 11 | salekhard
# Processing Record 24 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 25 of Set 11 | maldonado
# Processing Record 26 of Set 11 | annapolis
# Processing Record 27 of Set 11 | safaqis
# City not found. Skipping...
# Processing Record 28 of Set 11 | puerto suarez
# Processing Record 29 of Set 11 | balkhash
# Processing Record 30 of Set 11 | kargil
# Processing Record 31 of Set 11 | kruisfontein
# Processing Record 32 of Set 11 | jibuti
# Processing Record 33 of Set 11 | avallon
# Processing Record 34 of Set 11 | mokhotlong
# Processing Record 35 of Set 11 | laurens
# Processing Record 36 of Set 11 | gilgit
# Processing Record 37 of Set 11 | biltine
# Processing Record 38 of Set 11 | kaoma
# Processing Record 39 of Set 11 | vasai
# Processing Record 40 of Set 11 | general pico
# Processing Record 41 of Set 11 | yithion
# City not found. Skipping...
# Processing Record 42 of Set 11 | yanam
# Processing Record 43 of Set 11 | aleppo
# Processing Record 44 of Set 11 | varadero
# Processing Record 45 of Set 11 | tucuman
# Processing Record 46 of Set 11 | general roca
# Processing Record 47 of Set 11 | krasnoselkup
# Processing Record 48 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 49 of Set 11 | effingham
# Processing Record 50 of Set 11 | bell ville
# Processing Record 1 of Set 12 | humaita
# Processing Record 2 of Set 12 | pittsfield
# Processing Record 3 of Set 12 | pitkyaranta
# Processing Record 4 of Set 12 | sakaraha
# Processing Record 5 of Set 12 | charyshskoye
# Processing Record 6 of Set 12 | sao joao da barra
# Processing Record 7 of Set 12 | benghazi
# Processing Record 8 of Set 12 | puerto leguizamo
# Processing Record 9 of Set 12 | taga dzong
# City not found. Skipping...
# Processing Record 10 of Set 12 | santa cecilia
# Processing Record 11 of Set 12 | narsimhapur
# Processing Record 12 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 13 of Set 12 | huntington
# Processing Record 14 of Set 12 | kifri
# Processing Record 15 of Set 12 | varberg
# Processing Record 16 of Set 12 | tafresh
# Processing Record 17 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 18 of Set 12 | manta
# Processing Record 19 of Set 12 | sassandra
# Processing Record 20 of Set 12 | pitea
# Processing Record 21 of Set 12 | hammerfest
# Processing Record 22 of Set 12 | shache
# Processing Record 23 of Set 12 | south venice
# Processing Record 24 of Set 12 | mitsamiouli
# Processing Record 25 of Set 12 | nadym
# Processing Record 26 of Set 12 | barranca
# Processing Record 27 of Set 12 | uyemskiy
# Processing Record 28 of Set 12 | constitucion
# Processing Record 29 of Set 12 | kintampo
# Processing Record 30 of Set 12 | marsaxlokk
# Processing Record 31 of Set 12 | villa bruzual
# Processing Record 32 of Set 12 | iturama
# Processing Record 33 of Set 12 | feltre
# Processing Record 34 of Set 12 | batticaloa
# Processing Record 35 of Set 12 | bogota
# Processing Record 36 of Set 12 | canalete
# Processing Record 37 of Set 12 | traiguen
# Processing Record 38 of Set 12 | lawrenceburg
# Processing Record 39 of Set 12 | olafsvik
# Processing Record 40 of Set 12 | qarqin
# Processing Record 41 of Set 12 | matagami
# Processing Record 42 of Set 12 | tucurui
# Processing Record 43 of Set 12 | maceio
# Processing Record 44 of Set 12 | guatire
# Processing Record 45 of Set 12 | pisco
# Processing Record 46 of Set 12 | borujerd
# Processing Record 47 of Set 12 | inndyr
# Processing Record 48 of Set 12 | ndele
# Processing Record 49 of Set 12 | road town
# Processing Record 50 of Set 12 | soller
# Processing Record 1 of Set 13 | messina
# Processing Record 2 of Set 13 | mbanza-ngungu
# Processing Record 3 of Set 13 | selma
# Processing Record 4 of Set 13 | badarwas
# Processing Record 5 of Set 13 | paragominas
# Processing Record 6 of Set 13 | le port
# Processing Record 7 of Set 13 | baijiantan
# Processing Record 8 of Set 13 | irituia
# Processing Record 9 of Set 13 | port-gentil
# Processing Record 10 of Set 13 | hella
# Processing Record 11 of Set 13 | pangoa
# Processing Record 12 of Set 13 | sept-iles
# Processing Record 13 of Set 13 | zambezi
# Processing Record 14 of Set 13 | ittiri
# Processing Record 15 of Set 13 | wawa
# Processing Record 16 of Set 13 | yuksekova
# Processing Record 17 of Set 13 | padang
# Processing Record 18 of Set 13 | sambava
# Processing Record 19 of Set 13 | villazon
# Processing Record 20 of Set 13 | veraval
# Processing Record 21 of Set 13 | nagda
# Processing Record 22 of Set 13 | kotelnikovo
# Processing Record 23 of Set 13 | mullaitivu
# City not found. Skipping...
# Processing Record 24 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 25 of Set 13 | mitu
# Processing Record 26 of Set 13 | cassilandia
# Processing Record 27 of Set 13 | bereda
# Processing Record 28 of Set 13 | dno
# Processing Record 29 of Set 13 | bad wildungen
# Processing Record 30 of Set 13 | moisakula
# Processing Record 31 of Set 13 | umm kaddadah
# Processing Record 32 of Set 13 | pauini
# Processing Record 33 of Set 13 | shahr-e babak
# Processing Record 34 of Set 13 | erding
# Processing Record 35 of Set 13 | turukhansk
# Processing Record 36 of Set 13 | farafangana
# Processing Record 37 of Set 13 | brandon
# Processing Record 38 of Set 13 | saint-pierre
# Processing Record 39 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 40 of Set 13 | mizdah
# Processing Record 41 of Set 13 | sabla
# Processing Record 42 of Set 13 | florianopolis
# Processing Record 43 of Set 13 | sur
# Processing Record 44 of Set 13 | saint-leu
# Processing Record 45 of Set 13 | sao felix do xingu
# Processing Record 46 of Set 13 | ucar
# Processing Record 47 of Set 13 | lethem
# Processing Record 48 of Set 13 | north augusta
# Processing Record 49 of Set 13 | new amsterdam
# Processing Record 50 of Set 13 | ordynskoye
# Processing Record 1 of Set 14 | nokaneng
# Processing Record 2 of Set 14 | coxim
# Processing Record 3 of Set 14 | khandbari
# Processing Record 4 of Set 14 | berea
# Processing Record 5 of Set 14 | pangnirtung
# Processing Record 6 of Set 14 | huicungo
# Processing Record 7 of Set 14 | rudnichnyy
# Processing Record 8 of Set 14 | toulepleu
# City not found. Skipping...
# Processing Record 9 of Set 14 | cognac
# Processing Record 10 of Set 14 | oksfjord
# Processing Record 11 of Set 14 | pontes e lacerda
# Processing Record 12 of Set 14 | bani walid
# Processing Record 13 of Set 14 | taoudenni
# Processing Record 14 of Set 14 | muzhi
# Processing Record 15 of Set 14 | codajas
# Processing Record 16 of Set 14 | marsa matruh
# Processing Record 17 of Set 14 | muros
# Processing Record 18 of Set 14 | rumilly
# Processing Record 19 of Set 14 | bardiyah
# Processing Record 20 of Set 14 | santa rosa
# Processing Record 21 of Set 14 | beloha
# Processing Record 22 of Set 14 | pedasi
# Processing Record 23 of Set 14 | priiskovyy
# Processing Record 24 of Set 14 | rajec
# Processing Record 25 of Set 14 | lydenburg
# Processing Record 26 of Set 14 | annonay
# Processing Record 27 of Set 14 | neftcala
# Processing Record 28 of Set 14 | povenets
# Processing Record 29 of Set 14 | soyo
# Processing Record 30 of Set 14 | carlos antonio lopez
# Processing Record 31 of Set 14 | narasannapeta
# Processing Record 32 of Set 14 | baghdad
# Processing Record 33 of Set 14 | doka
# Processing Record 34 of Set 14 | esperantina
# Processing Record 35 of Set 14 | high rock
# Processing Record 36 of Set 14 | alekseyevka
# Processing Record 37 of Set 14 | mehar
# Processing Record 38 of Set 14 | moose factory
# Processing Record 39 of Set 14 | the valley
# Processing Record 40 of Set 14 | goumeron
# Processing Record 41 of Set 14 | george town
# Processing Record 42 of Set 14 | armacao dos buzios
# City not found. Skipping...
# Processing Record 43 of Set 14 | dembi dolo
# Processing Record 44 of Set 14 | isla mujeres
# Processing Record 45 of Set 14 | martinsville
# Processing Record 46 of Set 14 | nezhinka
# Processing Record 47 of Set 14 | yarkovo
# Processing Record 48 of Set 14 | badou
# Processing Record 49 of Set 14 | wagar
# Processing Record 50 of Set 14 | salamiyah
# Processing Record 1 of Set 15 | tucupita
# Processing Record 2 of Set 15 | kaupanger
# Processing Record 3 of Set 15 | betare oya
# Processing Record 4 of Set 15 | chone
# Processing Record 5 of Set 15 | larsnes
# Processing Record 6 of Set 15 | alibag
# Processing Record 7 of Set 15 | araguacu
# Processing Record 8 of Set 15 | storforshei
# Processing Record 9 of Set 15 | dunmore town
# Processing Record 10 of Set 15 | blyth
# Processing Record 11 of Set 15 | ati
# Processing Record 12 of Set 15 | atar
# Processing Record 13 of Set 15 | bury saint edmunds
# City not found. Skipping...
# Processing Record 14 of Set 15 | issoudun
# Processing Record 15 of Set 15 | iquique
# Processing Record 16 of Set 15 | tshikapa
# Processing Record 17 of Set 15 | sarankhola
# Processing Record 18 of Set 15 | myre
# Processing Record 19 of Set 15 | burica
# City not found. Skipping...
# Processing Record 20 of Set 15 | meulaboh
# Processing Record 21 of Set 15 | derzhavinsk
# Processing Record 22 of Set 15 | wolfsburg
# Processing Record 23 of Set 15 | gijon
# Processing Record 24 of Set 15 | wahran
# City not found. Skipping...
# Processing Record 25 of Set 15 | miracema do tocantins
# Processing Record 26 of Set 15 | kerki
# City not found. Skipping...
# Processing Record 27 of Set 15 | cheremisinovo
# Processing Record 28 of Set 15 | maraa
# Processing Record 29 of Set 15 | losal
# Processing Record 30 of Set 15 | surgut
# Processing Record 31 of Set 15 | manbij
# Processing Record 32 of Set 15 | zabol
# Processing Record 33 of Set 15 | sinor
# Processing Record 34 of Set 15 | cobija
# Processing Record 35 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 36 of Set 15 | cocachacra
# Processing Record 37 of Set 15 | santa marta
# Processing Record 38 of Set 15 | salym
# Processing Record 39 of Set 15 | rawson
# Processing Record 40 of Set 15 | tingi
# Processing Record 41 of Set 15 | vallenar
# Processing Record 42 of Set 15 | fenoarivo
# Processing Record 43 of Set 15 | znamenskoye
# Processing Record 44 of Set 15 | georgiyevskoye
# Processing Record 45 of Set 15 | maarianhamina
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 690

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Ushuaia -54.8000  -68.3000     56.86        72           0       12.66
# 1  Port Alfred -33.5906   26.8910     73.36        71           0       10.54
# 2    Inhambane -23.8650   35.3833     73.38        83          20        4.61
# 3     Sagarejo  41.7340   45.3315     23.43        95          99        2.57
# 4         Aksu  41.1231   80.2644     32.85        35          99        1.77
# 5    Bathsheba  13.2167  -59.5167     79.41        78          40       17.27
# 6   Vila Velha -20.3297  -40.2925     73.94        95          40        2.30
# 7     West Bay  19.3667  -81.4167     75.99        89           6        1.01
# 8    Busselton -33.6500  115.3333     86.97        34           0        5.12
# 9    Kirovskiy  45.0917  133.5136     13.03        89         100        8.75
#
#   Country Weather Description
# 0      AR           clear sky
# 1      ZA           clear sky
# 2      MZ          few clouds
# 3      GE     overcast clouds
# 4      CN     overcast clouds
# 5      BB    scattered clouds
# 6      BR    scattered clouds
# 7      KY           clear sky
# 8      AU           clear sky
# 9      RU          light snow

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Weather Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
columns_reorganized = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[columns_reorganized]

# Display sample data
city_data_df.head()
# Out:
#           City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0      Ushuaia      AR -54.8000 -68.3000     56.86        72           0
# 1  Port Alfred      ZA -33.5906  26.8910     73.36        71           0
# 2    Inhambane      MZ -23.8650  35.3833     73.38        83          20
# 3     Sagarejo      GE  41.7340  45.3315     23.43        95          99
# 4         Aksu      CN  41.1231  80.2644     32.85        35          99
#
#    Wind Speed Weather Description
# 0       12.66           clear sky
# 1       10.54           clear sky
# 2        4.61          few clouds
# 3        2.57     overcast clouds
# 4        1.77     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 690 non-null    object
#  1   Country              690 non-null    object
#  2   Lat                  690 non-null    float64
#  3   Lng                  690 non-null    float64
#  4   Max Temp             690 non-null    float64
#  5   Humidity             690 non-null    int64
#  6   Cloudiness           690 non-null    int64
#  7   Wind Speed           690 non-null    float64
#  8   Weather Description  690 non-null    object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 48.6+ KB

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
export_file = '../Weather_database/WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(export_file, index_label='City_ID')
